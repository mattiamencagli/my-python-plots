# %%
import numpy as np
import matplotlib.pylab as plt
import matplotlib

L = 1000
Oh = np.linspace(0.01,10,L)
Re = np.linspace(1,1000,L)

_ = plt.figure(1, figsize=[8,8])
_ = plt.loglog(Re, 50*Re**(-5./4.), "--",label="Onset of Splasching")
_ = plt.loglog(Re, 2.0/Re, label="Insufficent energy for rop formation")
_ = plt.hlines(0.1, min(Re), max(Re), "g", label="Satellite drops")
_ = plt.hlines(1, min(Re), max(Re), "r", label="Too viscous")
_ = plt.legend()
_ = plt.xlim(1,300)
_ = plt.ylim(0.01,10)
_ = plt.grid()
