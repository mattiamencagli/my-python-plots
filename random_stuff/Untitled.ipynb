# %%
import numpy as np
import matplotlib.pylab as plt
import matplotlib

R = 2.5
x = np.linspace(-R, R, 100)
y = np.linspace(-R, R, 100)
X, Y = np.meshgrid(x,y)

a = 2.5
b = 1

a2 = a*a
b2 = b*b

print("circ=%1.2f"%(2*np.pi*R))
print("circ=%1.2f"%(2*np.pi*np.sqrt(0.5*(a2+b2))))

_ = plt.figure(1, figsize=(6,6))
_ = plt.contour(X, Y, X*X + Y*Y - R*R, [0])
_ = plt.contour(X, Y, X*X/a2 + Y*Y/b2 - 1, [0])
_ = plt.xlim(-R*1.1,+R*1.1)
_ = plt.ylim(-R*1.1,+R*1.1)
_ = plt.grid()

_ = plt.figure(2, figsize=(6,6))
_ = plt.plot(bs, 2*np.pi*np.sqrt(0.5*(a2+bs*bs)))
_ = plt.grid()
# Out:
# circ=15.71
# circ=11.96
