# %%
def xorhex(hex1, hex2):
    # Conversione da esadecimale a decimale
    dec1 = int(hex1, 16)
    dec2 = int(hex2, 16)
    xor_result = dec1 ^ dec2
    print(f"a   : esadecimale={hex1:>2}, decimale={dec1:03d}, binario={bin(dec1)[2:].zfill(8)}")
    print(f"b   : esadecimale={hex2:>2}, decimale={dec2:03d}, binario={bin(dec2)[2:].zfill(8)}")
    print(f"a^b : esadecimale={hex(xor_result)[2:]:>2}, decimale={xor_result:03d}, binario={bin(xor_result)[2:].zfill(8)}")
    print()


xorhex('7d','20')
xorhex('7e','20')

xorhex('5d','20')
xorhex('5e','20')
# Out:
# a   : esadecimale=7d, decimale=125, binario=01111101
# b   : esadecimale=20, decimale=032, binario=00100000
# a^b : esadecimale=5d, decimale=093, binario=01011101
#
# a   : esadecimale=7e, decimale=126, binario=01111110
# b   : esadecimale=20, decimale=032, binario=00100000
# a^b : esadecimale=5e, decimale=094, binario=01011110
#
# a   : esadecimale=5d, decimale=093, binario=01011101
# b   : esadecimale=20, decimale=032, binario=00100000
# a^b : esadecimale=7d, decimale=125, binario=01111101
#
# a   : esadecimale=5e, decimale=094, binario=01011110
# b   : esadecimale=20, decimale=032, binario=00100000
# a^b : esadecimale=7e, decimale=126, binario=01111110
#
#  . b
