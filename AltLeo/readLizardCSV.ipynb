# %%
import csv
import numpy as np

file = 'C:/Users/Mattia Mencagli/Documents/DATA/output_lizard.csv'

print(f"Lizard .csv Header:\n0: NLOC; \n1: CCN; \n2: Token; \n3: Param; \n4: Number of lines; \
\n5: Detailed func name; \n6: File name; \n7: Func name; \n8: Func call; \n9: First line; \n10: Last line ")

toint = [0,1,2,3,4]
liz = []
buffer = ""

with open(file, 'r') as f:
    for line in f:
        line = line.rstrip('\n')  # Remove trailing newline

        if line.endswith('\\'):  # If line ends with `\`, join with next line
            buffer += line[:-1]  # Remove `\` and add to buffer
        else:
            if buffer:  # If buffer is not empty, prepend it to the current line
                line = buffer + line
                buffer = ""  # Reset buffer

            # Parse the line with csv.reader
            reader = csv.reader(StringIO(line))
            try:
                tmp = next(reader)
                # Convert specified columns to int
                for i in toint:
                    tmp[i] = int(tmp[i])
                liz.append(tmp)
            except StopIteration:
                # Skip empty lines
                continue
# Out:
# Lizard .csv Header:
# 0: NLOC;
# 1: CCN;
# 2: Token;
# 3: Param;
# 4: Number of lines;
# 5: Detailed func name;
# 6: File name;
# 7: Func name;
# 8: Func call;
# 9: First line;
# 10: Last line

# %%
total = len(liz)

CCNlim = 20
highCCN = []
summ = 0 
for l in liz:
    if l[1]>CCNlim:
        summ += 1
        highCCN.append(l[5])
print(f"tot={total}; CCN>{CCNlim}? {summ}")

NLOCs = np.array([sublist[0] for sublist in liz])
NCCs  = np.array([sublist[1] for sublist in liz])

avg_NLOC = np.average(NLOCs)
avg_CCN = np.average(NCCs)
print(f"avg_NLOC:{avg_NLOC:.1f}; avg_CCN:{avg_CCN:.1f}")
# Out:
# tot=7525; CCN>20? 106
# avg_NLOC:15.4; avg_CCN:3.1

# %%
highCCN
# Out:
# ['Xsens::readMessage@696-835@./M0285PCAAP01_PcaApp/modules/imugps/src/pca/modules/imugps/xsens/Xsens.cpp',
#  'M900::receiveData@277-475@./M0285PCAAP01_PcaApp/modules/hcu/src/pca/modules/hcu/atoms/M900.cpp',
#  'HcuMultiMode::receiveData@160-295@./M0285PCAAP01_PcaApp/modules/hcu/src/pca/modules/hcu/HcuMultiMode.cpp',
#  'Dg231::receiveData@296-489@./M0285PCAAP01_PcaApp/modules/hcu/src/pca/modules/hcu/daco/Dg231.cpp',
#  'S727::receiveData@304-561@./M0285PCAAP01_PcaApp/modules/hcu/src/pca/modules/hcu/leonardo/S727.cpp',
#  'pca::modules::hcu::Hcu::PushStepButton::setState@512-588@./M0285PCAAP01_PcaApp/modules/hcu/src/pca/modules/hcu/Hcu.h',
#  'pca::modules::hcu::Hcu::TwoWayPushButton::setState@618-718@./M0285PCAAP01_PcaApp/modules/hcu/src/pca/modules/hcu/Hcu.h',
#  'pca::modules::hcu::Hcu::FourWayPushButton::setState@748-900@./M0285PCAAP01_PcaApp/modules/hcu/src/pca/modules/hcu/Hcu.h',
#  'HcuSingleMode::receiveData@112-217@./M0285PCAAP01_PcaApp/modules/hcu/src/pca/modules/hcu/HcuSingleMode.cpp',
#  'VideoEncoder::startRecorder@113-527@./M0285PCAAP01_PcaApp/modules/videoencoder/src/pca/modules/videoencoder/VideoEncoder.cpp',
#  'VideoEncoder::startStreamer@535-903@./M0285PCAAP01_PcaApp/modules/videoencoder/src/pca/modules/videoencoder/VideoEncoder.cpp',
#  'MenuItem::MenuItem@15-144@./M0285PCAAP01_PcaApp/modules/gui/src/pca/modules/gui/base/MenuItem.cpp',
#  'Frame::setAnchor@185-274@./M0285PCAAP01_PcaApp/modules/gui/src/pca/modules/gui/base/Frame.cpp',
#  'SystemMenuWindow::setMenuNavigation@171-328@./M0285PCAAP01_PcaApp/modules/gui/src/pca/modules/gui/widget/SystemMenuWindow.cpp',
#  'LaserInfo::toString@154-453@./M0285PCAAP01_PcaApp/modules/gui/src/pca/modules/gui/widget/LaserInfo.cpp',
#  'MissionWindow::setMenuNavigation@159-358@./M0285PCAAP01_PcaApp/modules/gui/src/pca/modules/gui/widget/MissionWindow.cpp',
#  'PlatformPositionInfo::toString@160-293@./M0285PCAAP01_PcaApp/modules/gui/src/pca/modules/gui/widget/PlatformPositionInfo.cpp',
#  'SystemInfo::toString@69-112@./M0285PCAAP01_PcaApp/modules/gui/src/pca/modules/gui/widget/SystemInfo.cpp',
#  'VideoWindow::Render::Overlay::updateView@89-907@./M0285PCAAP01_PcaApp/modules/gui/src/pca/modules/gui/widget/VideoWindowRenderOverlay.cpp',
#  'MapWindow::customPaint@209-547@./M0285PCAAP01_PcaApp/modules/gui/src/pca/modules/gui/widget/MapWindow.cpp',
#  'TargetPositionInfo::toString@294-405@./M0285PCAAP01_PcaApp/modules/gui/src/pca/modules/gui/widget/TargetPositionInfo.cpp',
#  'SystemMenuGraphics::setMenuNavigation@382-542@./M0285PCAAP01_PcaApp/modules/gui/src/pca/modules/gui/widget/SystemMenuGraphics.cpp',
#  'GuiHD::MainFrame::updateView@655-847@./M0285PCAAP01_PcaApp/modules/gui/src/pca/modules/gui/GuiHDMainFrame.cpp',
#  'Avt::process@165-654@./M0285PCAAP01_PcaApp/modules/avt/src/pca/modules/avt/Avt.cpp',
#  'Avt::acquisition@868-1037@./M0285PCAAP01_PcaApp/modules/avt/src/pca/modules/avt/Avt.cpp',
#  'Avt::labelTarget@1074-1260@./M0285PCAAP01_PcaApp/modules/avt/src/pca/modules/avt/Avt.cpp',
#  'Avt::centroidTracker@1707-2166@./M0285PCAAP01_PcaApp/modules/avt/src/pca/modules/avt/Avt.cpp',
#  'Avt::updateTargetWindow@2171-2331@./M0285PCAAP01_PcaApp/modules/avt/src/pca/modules/avt/Avt.cpp',
#  'Avt::correlateTracker@2832-3103@./M0285PCAAP01_PcaApp/modules/avt/src/pca/modules/avt/Avt.cpp',
#  'Avt::correlationNCC@3140-3442@./M0285PCAAP01_PcaApp/modules/avt/src/pca/modules/avt/Avt.cpp',
#  'Avt::rescaleCorrWindow@3510-3664@./M0285PCAAP01_PcaApp/modules/avt/src/pca/modules/avt/Avt.cpp',
#  'FusionProfiles::loadFusionTables@320-607@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/profiles/FusionProfiles.cpp',
#  'FusionProfiles::getCorrectedFovFromFovPositon@1049-1232@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/profiles/FusionProfiles.cpp',
#  'Sys::initGuiModules@3010-3177@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/Sys.cpp',
#  'Sys::ibitEndAction@3515-3556@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/Sys.cpp',
#  'Sys::geoLocationActionWhileSteering@3985-4240@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/Sys.cpp',
#  'Sys::geoVelocityAction@4245-4387@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/Sys.cpp',
#  'Sys::geoPointAction@4628-4874@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/Sys.cpp',
#  'Sys::bitEventHandler@6653-6795@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/Sys.cpp',
#  'operator < <@7028-7164@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/Sys.cpp',
#  'operator < <@13-59@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/System.cpp',
#  'DebugParams::resetMaintParameters@35-1045@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/SysDebugParams.cpp',
#  'ControlLoop::XYTargetToLosRate@164-470@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/SysControlLoop.cpp',
#  'Sys::GuiControl::loadContextMenuActualValues@1055-1530@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/SysGuiControl.cpp',
#  'Sys::GuiControl::showContextMenu@1535-1623@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/SysGuiControl.cpp',
#  'Sys::GuiControl::changeMainCamera@2090-2282@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/SysGuiControl.cpp',
#  'Sys::GuiControl::startStopVideoRecording@3169-3348@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/SysGuiControl.cpp',
#  'Sys::GuiControl::hcuAuxFunction@3781-3856@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/SysGuiControl.cpp',
#  'Sys::GuiControl::updateContextMenu@3974-4041@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/SysGuiControl.cpp',
#  'Sys::GuiControl::systemMenuValueChanged@4048-8950@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/SysGuiControl.cpp',
#  'Sys::GuiControl::onContextMenuValueChanged@9039-9533@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/SysGuiControl.cpp',
#  'Sys::GuiControl::updateSystemMenu@9571-12843@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/SysGuiControl.cpp',
#  'Sys::GuiControl::initSystemMenu@12914-16281@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/SysGuiControl.cpp',
#  'Sys::NavigationControl::internalNavigation@502-1101@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/SysNavigationControl.cpp',
#  'Sys::NavigationControl::externalNavigation@1110-1446@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/SysNavigationControl.cpp',
#  'Sys::SpaControl::spaInOperativeAction@1279-1403@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/SysSpaControl.cpp',
#  'Sys::SpaControl::receive@2325-2714@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/SysSpaControl.cpp',
#  'Sys::SpaControl::onGetParamModuleResult@4310-4341@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/SysSpaControl.cpp',
#  'Sys::HcuControlInterface::LndSHCUS727::pushPressed@197-355@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/hcucontrol/SysHcuControlLndSHCUS727.cpp',
#  'TraceDataCollector::toLaserStatus@1056-1284@./M0285PCAAP01_PcaApp/modules/sys/src/pca/modules/sys/SysDataCollector.cpp',
#  'KlvParser::parseByte@43-288@./M0285PCAAP01_PcaApp/modules/stanag/src/pca/modules/stanag/4609/KlvParser.cpp',
#  'Bit::failCodeIngest@136-205@./M0285PCAAP01_PcaApp/modules/bit/src/pca/modules/bit/Bit.cpp',
#  'Bit::monitoringTemperaturesVsPart@230-388@./M0285PCAAP01_PcaApp/modules/bit/src/pca/modules/bit/Bit.cpp',
#  'Bit::monitoringTemperaturesVsSru@393-647@./M0285PCAAP01_PcaApp/modules/bit/src/pca/modules/bit/Bit.cpp',
#  'Spa::setSerialBridge@730-808@./M0285PCAAP01_PcaApp/modules/spa/src/pca/modules/spa/Spa.cpp',
#  'Spa::dataIngest@3814-4283@./M0285PCAAP01_PcaApp/modules/spa/src/pca/modules/spa/Spa.cpp',
#  'GeoCoordinate::toString@339-444@./M0285PCAAP01_PcaApp/modules/geo/src/pca/modules/geo/GeoCoordinate.cpp',
#  'GeoLocalization::passive@97-417@./M0285PCAAP01_PcaApp/modules/geo/src/pca/modules/geo/GeoLocalization.cpp',
#  'GeoLocalization::footprint@429-659@./M0285PCAAP01_PcaApp/modules/geo/src/pca/modules/geo/GeoLocalization.cpp',
#  'GPSMultiSource::addGPSPrimaryData@138-349@./M0285PCAAP01_PcaApp/modules/geo/src/pca/modules/geo/GpsMultiSource.cpp',
#  'Geo::pointing@314-790@./M0285PCAAP01_PcaApp/modules/geo/src/pca/modules/geo/Geo.cpp',
#  'Geo::pointing_new@800-1203@./M0285PCAAP01_PcaApp/modules/geo/src/pca/modules/geo/Geo.cpp',
#  'Geo::pointing_ff@1216-1591@./M0285PCAAP01_PcaApp/modules/geo/src/pca/modules/geo/Geo.cpp',
#  'ButterworthLowPassFilter::filter@29-71@./M0285PCAAP01_PcaApp/modules/geo/src/pca/modules/geo/ButterworthLowPassFilter.cpp',
#  'GeoScan::geoScan@27-263@./M0285PCAAP01_PcaApp/modules/geo/src/pca/modules/geo/GeoScan.cpp',
#  'Vicom2::configure@1028-1228@./M0285PCAAP01_PcaApp/modules/bsp/src/pca/modules/bsp/Vicom2.cpp',
#  'Stream::nextFrame@813-989@./M0285PCAAP01_PcaApp/modules/video/src/pca/modules/video/Stream.cpp',
#  'Processing::process@536-1009@./M0285PCAAP01_PcaApp/modules/video/src/pca/modules/video/Processing.cpp',
#  'Sta380::parseCbitFails@691-871@./M0285PCAAP01_PcaApp/modules/sta/src/pca/modules/sta/sta380/Sta380.cpp',
#  'Sta380::receiveMessage@1177-1517@./M0285PCAAP01_PcaApp/modules/sta/src/pca/modules/sta/sta380/Sta380.cpp',
#  'Sta380::toMode@1587-1689@./M0285PCAAP01_PcaApp/modules/sta/src/pca/modules/sta/sta380/Sta380.cpp',
#  'Sta380::parseFlags@1695-1792@./M0285PCAAP01_PcaApp/modules/sta/src/pca/modules/sta/sta380/Sta380.cpp',
#  'Ssh::attemptPull@722-939@./M0285PCAAP01_PcaApp/modules/core/src/pca/modules/core/Ssh.cpp',
#  'MTI::update_v_history@1182-1287@./M0285PCAAP01_PcaApp/modules/ivp/src/pca/modules/ivp/cpu/mti/MTI.cpp',
#  'MTI::scanMovingObjects@1395-1633@./M0285PCAAP01_PcaApp/modules/ivp/src/pca/modules/ivp/cpu/mti/MTI.cpp',
#  'MTI::clusterFollow@1638-1749@./M0285PCAAP01_PcaApp/modules/ivp/src/pca/modules/ivp/cpu/mti/MTI.cpp',
#  'MTI::performSeq@1884-2182@./M0285PCAAP01_PcaApp/modules/ivp/src/pca/modules/ivp/cpu/mti/MTI.cpp',
#  'MTI_Record::save@490-683@./M0285PCAAP01_PcaApp/modules/ivp/src/pca/modules/ivp/cpu/mti/MTI_record.cpp',
#  'Ivp::deHaze@546-1074@./M0285PCAAP01_PcaApp/modules/ivp/src/pca/modules/ivp/cpu/Ivp.cpp',
#  'FusionPreprocess::process@75-240@./M0285PCAAP01_PcaApp/modules/ivp/src/pca/modules/ivp/cuda/CudaFusionPreprocess.cpp',
#  'FmsAW169::onLabels@63-437@./M0285PCAAP01_PcaApp/modules/extsys/src/pca/modules/extsys/fms-aw169/FmsAW169.cpp',
#  'FmsAW139::onLabels@63-305@./M0285PCAAP01_PcaApp/modules/extsys/src/pca/modules/extsys/fms-aw139/FmsAW139.cpp',
#  'IrsNH90::onLabels@69-369@./M0285PCAAP01_PcaApp/modules/extsys/src/pca/modules/extsys/irs-nh90/IrsNH90.cpp',
#  'AhrsAW139::onLabels@224-587@./M0285PCAAP01_PcaApp/modules/extsys/src/pca/modules/extsys/ahrs-aw139/AhrsAW139.cpp',
#  'Observer::toSystemMode@32-65@./M0285PCAAP01_PcaApp/modules/extsys/src/pca/modules/extsys/observer/Observer.cpp',
#  'Observer::receiveMessage@544-674@./M0285PCAAP01_PcaApp/modules/extsys/src/pca/modules/extsys/observer/Observer.cpp',
#  'InputPacket::decodeMessage@98-1058@./M0285PCAAP01_PcaApp/modules/extsys/src/pca/modules/extsys/leoss-rcp-serial/LeossRcpSerialPacket.cpp',
#  'LeossRcpSerialChannel::manageCommandMessage@432-755@./M0285PCAAP01_PcaApp/modules/extsys/src/pca/modules/extsys/leoss-rcp-serial/LeossRcpSerialChannel.cpp',
#  'LeossRcpSerialChannel::received_SET_OUTPUT_Command@1658-1858@./M0285PCAAP01_PcaApp/modules/extsys/src/pca/modules/extsys/leoss-rcp-serial/LeossRcpSerialChannel.cpp',
#  'LeossRcpSerialHelper::SystemStateToMode@366-437@./M0285PCAAP01_PcaApp/modules/extsys/src/pca/modules/extsys/leoss-rcp-serial/LeossRcpSerialHelper.cpp',
#  'LeossRcpSerialHelper::SystemStateToSystemMode@695-785@./M0285PCAAP01_PcaApp/modules/extsys/src/pca/modules/extsys/leoss-rcp-serial/LeossRcpSerialHelper.cpp',
#  'InatAtos::onLabels@74-573@./M0285PCAAP01_PcaApp/modules/extsys/src/pca/modules/extsys/inat-atos/InatAtos.cpp',
#  'Atos::toSystemMode@56-90@./M0285PCAAP01_PcaApp/modules/extsys/src/pca/modules/extsys/atos/Atos.cpp',
#  'Atos::receiveMessage@812-983@./M0285PCAAP01_PcaApp/modules/extsys/src/pca/modules/extsys/atos/Atos.cpp',
#  'Lcb::dataIngest@833-1082@./M0285PCAAP01_PcaApp/modules/lcb/src/pca/modules/lcb/Lcb.cpp',
#  'HwInfo::printCudaDeviceInfo@321-550@./M0285PCAAP01_PcaApp/tools/hw-info/HwInfo.cpp']
